# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from collections import Counter

# %%
train = pd.read_pickle('train.p')
train.keys()
# Out:
# dict_keys(['coords', 'labels', 'features', 'sizes'])

# %%
 X_train, y_train = train['features'], train['labels']
 X_train.shape, y_train.shape
# Out:
# ((34799, 32, 32, 3), (34799,))

# %% [markdown]
# #Visualisation

# %%
plt.imshow( X_train[100] );

# %%
signs = pd.read_csv('signnames.csv')
signs.head()
# Out:
#    a                     b
# 0  0  Speed limit (20km/h)
# 1  1  Speed limit (30km/h)
# 2  2  Speed limit (50km/h)
# 3  3  Speed limit (60km/h)
# 4  4  Speed limit (70km/h)

# %%
#Create a vocabulary for Signanmes.csv
dict_signs = signs.to_dict()['b']
dict_signs[25]
# Out:
# 'Road work'

# %%
X_train[ y_train == 30].shape
# Out:
# (390, 32, 32, 3)

# %%
#Iterate over the whole dataset and visualise around 5-10

for id_sign in dict_signs.keys():
  given_signs = X_train[ y_train == id_sign]

  plt.figure(figsize=(15,5))
  for i in range(9):
    plt.subplot('19{0}'.format(i+1) )
    plt.imshow( given_signs [i] )
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#Let's count how many signs do we have per each 
cnt = Counter(y_train).most_common()
cnt


#create two lists with id and count values
id_labels, cnt_labels = zip(*cnt)
ids = range(len(id_labels))

plt.figure(figsize=(15,5))
plt.bar(ids, cnt_labels)

plt.xlabel('Signs')
labels = [dict_signs[ id_labels[id_] ] for id_ in id_labels]
plt.xticks(ids, labels, rotation='vertical');

plt.title('Road signs')
plt.show()
